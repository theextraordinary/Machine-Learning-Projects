# %%
import twint
import nest_asyncio
nest_asyncio.apply()

twint.__version__

c = twint.Config()

c.Lang='en'
# c.Location=True

c.Search=['nike','Nike']
# c.Pandas=True
c.Limit=10000
c.Store_csv=True
c.Output=r'./nike.csv'
twint.run.Search(c)
# nike_df = twint.storage.panda.Tweets_df
# Out:
# 1469254880401723395 2021-12-10 16:07:15 +0530 <LoopM6> Check out this listing I just added to my #Poshmark closet: NIKE ZOOM KD10 Durant LMTD "BHM" Black History Month Rare Sz 11.5.  https://t.co/0wnoGJxZFP #shopmycloset @poshmarkapp
# 1469254845790134278 2021-12-10 16:07:07 +0530 <ltadori_> @qlff_6vnis Nike crosstrainer
# 1469254766236962821 2021-12-10 16:06:48 +0530 <Yoon_Nike00> @tree_ss_joa 토게.! 일려나요!
# 1469254702986678275 2021-12-10 16:06:33 +0530 <ririsan_17> @lolo7895 Après ce qu’il veut dire c’est que Nike a créer sa marque sa notoriété son pouvoir seul et mtn peut se permettre de juste coller leur logo grâce à l’image de marque
# 1469254668161323008 2021-12-10 16:06:24 +0530 <NobleHandi> @theestallion @Nike Congratulations 🎊🎉🎈
# 1469254615363616769 2021-12-10 16:06:12 +0530 <nike_CamoShiro> 無理矢理  https://t.co/B9eLFyhakW
# ...
